# %%
import torch
from torch import nn

# %%
import matplotlib.pyplot as plt

# %%
torch.__version__

# %%
weight , bias = 0.7,0.3

# %%
start = 0
end = 1
step = 0.02
X = torch.arange(start,end,step).unsqueeze(dim=1)
y = weight * X + bias

# %%
X[:10],y[:10]

# %%
train_split = int(0.8*len(X))
train_split

# %%
train_split = int(0.8*len(X))
x_train,y_train = X[:train_split],y[:train_split]
x_test , y_test = X[train_split:],y[train_split:]

# %%
len(x_train), len(x_test) , len(y_train), len(y_test)

# %%
def plot_predictions(train_data = x_train, train_labels=y_train,
                    test_data=x_test, test_labels=y_test,
                    predictions=None):
    plt.figure(figsize=(8,6))
    plt.scatter(train_data,train_labels, c="b", s=4, label= "Training Date") # c= color , s= size
    plt.scatter(test_data, test_labels, c="g", s=4, label="Test Data")
    
    if predictions is not None:
        plt.scatter(test_data, predictions, c="r",s=4, label="Predictions")

    plt.legend(prop={"size":14})

# %%
plot_predictions()

# %% [markdown]
# #### pytroch model for linear regression

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(1,
                                                requires_grad=True,
                                                dtype=torch.float))
        self.bias = nn.Parameter(torch.randn(1,
                                            requires_grad=True,
                                            dtype=torch.float))
    # forward method
    def forward(self, x:torch.Tensor) -> torch.Tensor: 
        return self.weights*x + self.bias

# %%
torch.manual_seed(42)
model_0 = LinearRegressionModel()
model_0 , model_0.parameters()

# %%
type(model_0)

# %%
list(model_0.parameters())

# %%
model_0.state_dict()

# %%
weight , bias

# %%
x_test, y_test

# %%
import time
start_time = time.time()
y_preds = model_0(x_test)
end_time = time.time()
total_time = end_time = start_time
total_time

# %%
y_preds

# %%
import time
with torch.inference_mode():
    start_time = time.time()
    y_preds = model_0(x_test)
    total_time = end_time = start_time
    print(total_time)

y_preds

# %%
plot_predictions(predictions=y_preds)

# %%
import time
with torch.no_grad():
    start_time = time.time()
    y_preds = model_0(x_test)
    total_time = end_time = start_time
    print(total_time)

# %% [markdown]
# ##### loss function tells how  much wrong the model is
# ##### optimizere adjusts the model parameters

# %% [markdown]
# ##### traning loop
# 0. loop through the data
# 1. forward pass
# 2. calcualte the loss
# 3. optimizer zero grad
# 4. loss backward
# 5. optimizer step

# %%
epochs = 10 # an one epoch is one loop thourgh the data

# %%
with torch.inference_mode():
    print(model_0.state_dict())
    print(list(model_0.parameters()))

# %%
with torch.inference_mode():
    y = model_0(x_test)
    print(y)
    print(type(y))
    print(y.requires_grad)

# %%
with torch.no_grad():
    print(model_0.state_dict())
    print(list(model_0.parameters()))

# %%
model_0.eval()
print(list(model_0.parameters()))
model_0.train()
print(list(model_0.parameters()))

# %%
loss = nn.L1Loss()
optimizer = torch.optim.SGD(params=model_0.parameters(),lr=0.1)  # lr is learning rate default is 0.1

# %%
model_0.parameters()

# %%
# total number of parameters in a model
sum(p.numel() for p in model_0.parameters())

# %%
for epoch in range(epochs):

    model_0.train() # this is the default mode

    # print("Before:", model_0.weights.data)

    y_pred = model_0(x_train)   

    loss_value = loss(y_pred, y_train)

    optimizer.zero_grad()

    loss_value.backward()

    # print("Grad:", model_0.weights.grad)

    optimizer.step()

    # print("After:", model_0.weights.data)

# %% [markdown]
# ###### test with both random and with zero variables in the model

# %%
test = torch.tensor(10)

# %%
import time
with torch.inference_mode():
    model_0.eval()
    start_time = time.time()
    y_preds = model_0(test)
    total_time = end_time - start_time
    print(total_time)

y_preds

# %%
plot_predictions(predictions=y_preds)

# %%
import torch

# fake data
x_train = torch.tensor([1., 2., 3., 4.])
y_train = torch.tensor([3., 5., 7., 9.])

# parameters
w = torch.tensor(0.0)
b = torch.tensor(0.0)

# learning rate
lr = 0.01

epochs = 100

# %%
for epoch in range(epochs):

    # forward pass
    y_pred = w * x_train + b

    # MSE loss
    loss = ((y_pred - y_train) ** 2).mean()

    # MANUAL gradients
    # derivative of loss wrt w
    dw = (2 * ((y_pred - y_train) * x_train)).mean()

    # derivative of loss wrt b
    db = (2 * (y_pred - y_train)).mean()

    # manual parameter update
    w = w - lr * dw
    b = b - lr * db

    if epoch % 10 == 0:
        print(f"Epoch {epoch}")
        print(f"w: {w}, b: {b}")
        print(f"loss: {loss}")
        print()
# Out:
# Epoch 0
# w: 0.3499999940395355, b: 0.11999999731779099
# loss: 41.0
#
# Epoch 10
# w: 1.8132834434509277, b: 0.6271117329597473
# loss: 1.0733331441879272
#
# Epoch 20
# w: 2.0463268756866455, b: 0.7155136466026306
# loss: 0.0396033376455307
#
# Epoch 30
# w: 2.0815560817718506, b: 0.7363646626472473
# loss: 0.012169554829597473
#
# Epoch 40
# w: 2.085033655166626, b: 0.7461544275283813
# loss: 0.010811055079102516
#
# Epoch 50
# w: 2.0834686756134033, b: 0.7539747953414917
# loss: 0.01016497053205967
#
# Epoch 60
# w: 2.081155300140381, b: 0.7612940073013306
# loss: 0.009572885930538177
#
# Epoch 70
# w: 2.078782796859741, b: 0.7683535814285278
# loss: 0.009015659801661968
#
# Epoch 80
# w: 2.0764594078063965, b: 0.7751975059509277
# loss: 0.008490930311381817
#
# Epoch 90
# w: 2.0742015838623047, b: 0.7818381190299988
# loss: 0.007996692322194576
